# %%
import csv
import random as rand

#use the following part to add data for csv file:
with open('comments.csv', 'w') as f:
    f.write("Name,Grade,Test/Quizzes,Misses HW,Projects,Engagement,Collaboration, Pronounce, Character,Second Character\n")
    f.write("Kanye,97,90,1,95,1,4,he,1,4\n")
    f.write("Andrew,93,98,4,95,3,2,she,3,2\n")
    f.write("Alex,82,81,3,95,3,4,they,2,1\n")

f = open('comments.csv')
data = csv.reader(f, delimiter = ',')
header = f.readline().split(',')

def overall_grade_engagement_collaboration(data):
    #determine the pronounce and possessive
    if row[7].lower() == 'he':
        pronounce = 'he'
        possessive = 'his'
    if row[7].lower() == 'she':
        pronounce = 'she'
        possessive = 'her'
    if row[7].lower() == 'they':
        pronounce = 'they'
        possessive = 'their'
    #a is the output string of the function
    a = ''
    #since we don't want everyone to have the same comments, the random package is used to diverse the comments, even if two students have exact same grades
    b = rand.choice([1,2])
    #grade comment
    if int(row[1]) >= 93:
        a += (row[0] + ' has an A in the class. ')
    if 88 <= int(row[1]) <= 92:
        a += (row[0] + "'s grade lies in the B+/A- range. ")
    if 84 <= int(row[1]) <= 87:
        a += (row[0] + ' has a B right now for this class. ')
    if int(row[1]) <= 83:
        a += (row[0] + ' has a B- right now for the class. ')
    #choice 1 for engagement and collaboration comments
    if b == 1:
        if int(row[5]) >= 3:
            a += (pronounce.title() + ' has good engagement and focus in the class. ' + pronounce.title() + ' contributes a lot of valuable ideas in class, and brings the discussions to the new level. ')
        if int(row[5]) < 3:
            a += (pronounce.title() + ' should engage more in class by contributing to the discussion. However, I can tell that ' + pronounce + ' knows what is going on class, and constantly thinks about it. ')
        if int(row[6]) >= 3:
            a += (pronounce.title() + ' collaborates well with ' + possessive + ' friends during group works and projects. The projects all turn out very well.')
        if int(row[6]) < 3:
            a += (pronounce.title() + ' just needs to work on communicating with ' + possessive + ' peers in projects and group work. I will be very happy if you can have more confidence in group works and discussions.')
    #choice 2 for engagement and collaboration comments
    if b == 2:
        if int(row[5]) >= 3:
            a += (pronounce.title() + ' pays good attention in class. ' + pronounce.title() + ' attentively brings well-thought and critical ideas to the class discussions. ')
        if int(row[5]) < 3:
            a += (pronounce.title() + ' may be quiet in class, but I can tell that ' + pronounce + ' knows what is going on class, and constantly thinks about it. ' + row[0] + ' just need a little bit more confidence. ')
        if int(row[6]) >= 3:
            a += (pronounce.title() + ' is very amiable and motivated with ' + possessive + ' friends during group works and projects. ' + pronounce + ' knows how to collaborate with ' + possessive + ' peers to improve the works significantly. ')
        if int(row[6]) < 3:
            a += (pronounce.title() + ' works well with ' + possessive + ' peers in projects and group work, but maybe ' + pronounce + ' just needs a little bit more communication with ' + possessive + ' friends. ')
    #since 'they' changes the grammar, this part replaces all the verbs and grammar mistakes
    if pronounce == 'they':
        a = a.replace('They has','They have')
        a = a.replace('collaborates', 'collaborate')
        a = a.replace('needs','need')
        a = a.replace('brings','bring')
        a = a.replace('knows','know')
        a = a.replace('thinks','think')
        a = a.replace('contributes','contribute')
        a = a.replace('pays','pay')
        a = a.replace(' is ',' are ')
        a = a.replace('works','work')
    return a

def area_to_improve(row):
    pronouns = []
    #the function first determines the students appropriate pronouns and stores them to a list called pronouns
    if row[7] == "he":
        pronouns = ["he", "him", "his"]
    elif row[7] == "she":
        pronouns = ["she", "her", "her"]
    else:
        pronouns = ["they", "them", "their"]
    name = row[0] #Next we store the students name under the variable 'name"
    comps = [] #Next we define a list that will store each whole part of the areas to improve comment, that will be stitched together later
    final = "" #Next we declare the variable 'final' which will be the output of the function
    areas = [] #Next we create a list which will store the areas that we flagged, the following line is a list of tuples of area names and the students performance in that area
    areatuples = []
    grade = int(row[1]) #The following seven lines determines the students most weak area (provided it is under 94) and adds it to the list of areas to improve
    tq = int(row[2])
    areatuples.append((tq, "TQ"))
    pro = int(row[4])
    areatuples.append((pro, "PRO"))
    if min(areatuples)[0] <94:
        areas.append(min(areatuples)[1])
    hw = int(row[3]) 
    col = int(row[6])
    if hw > 2: #Because hw is measured on a completion metric, we use a different function to decide wether to flag it, adding it only if the students is missing more than two assignments
        areas.append("HW")    
    #The next set of three if statements use the following logic, if the area in question (homework, projects, or tests and quizzes) has been flagged, the function will add on of three randomly chosen topic sentences that all say something to the effect of "they need to do X better" then depending other sujbect area dependent variables, if statements will also add another sentence or two relevant to the sudents particular situation.
    if ("HW") in areas:
        text = ["One area where",name,"could improve is consistently turning in homework assignments.", name, "had", str(hw), "missing assignments this semester and homework is an essential aspect of this class. If", name, "is having trouble with the homework, I would recommend trying to find some peers to do it with or", pronouns[0], "is always welcome to come ask me questions."]
        ftext = " ".join(text)
        comps.append(ftext)
    if ("PRO") in areas:
        text = ["An area where", name, "could place more focus is projects."]
        if pro < grade:
            temp = [name, "has a", str(pro), "grade for projects which is dragging down", pronouns[2], "overall grade in the class. Projects are a great opportunity to improve your overall grade in the class, especially if you aren't at your best in a testing environment."]
            for item in temp:
                text.append(item)
        elif col <=2:
            temp = ["One aspects of project work that", name, "seems to struggle with is group work. While I understand that group work can be frustrating at times, it is an essential skill that is well worth developing."]
            for item in temp:
                text.append(item)
        ftext = " ".join(text)
        comps.append(ftext) 
    if ("TQ") in areas:
        text = ["Tests and quizzes were an area where", name, "could stand to put a little more focus."]
        if tq < grade:
            temp = ["If", name, "feels like", pronouns[0],"is understanding the material but are still struggling with the tests, I would be happy to work with", pronouns[1], "on test taking strategies."]
            for item in temp:
                    text.append(item)
        else:
            temp = ["Assesments are an excellent opportunity for students to demonstrate their learning from the unit. If", name, "feels like", pronouns[0], "is struggling to learn the material, I would recommend finding peers to discuss the lesson with or talking to me."]
            for item in temp:
                    text.append(item)
        ftext = " ".join(text)
        comps.append(ftext)
        
    if len(areas) == 0: #if the student has no grades underneath 94 and two or fewer missing assignments, the function adds a special couple of lines reflecting that.
        text = [name, "has no specific areas for improvement, and I hope that", pronouns[0], "continues to be an engaged learner through the rest of the class. If", name, "is looking for more challenge", pronouns[0], "should come talk to me about finding some more advacned material that might be of interest."]
        ftext = " ".join(text)
        comps.append(ftext)
    final = " ".join(comps)
    final = final.replace("they is","they are").replace("they continues","they continue") # this line fixes errors in subject verb agreement that result in the differing plurality of the 'they' and 'he/she'
    return(final)


def character_traits(words):
    final = ""
    name = words[0]
#now we determine pronouns.
    if words[7] == "he":
        pronouns = ["he", "him", "his"]
    if words[7] == "she":
        pronouns = ["she", "her", "her"]
    if words[7] == "they":
        pronouns = ["they", "them", "their"]
#here, we make a loop with the section of each line that has character traits. It is open-ended to accomodate for several traits.
    for word in words[8:]:
        if str(word) == "1":
            final += (rand.choice([name+' has a great work ethic, always diligent and thorough with '+pronouns[2]+' assignments and projects. '+pronouns[2].title()+' attention to work is a great quality.',
                                           'Even under pressure or with difficult problems, '+name+' is always ready to correct mistakes and improve. '+pronouns[2].title()+' perseverance is commendable.',
                                           name+' has shown '+pronouns[2]+' great work ethic through '+pronouns[2]+' tireless effort to improve '+pronouns[1]+'self, having shown great progress in '+pronouns[2]+' previous areas that needed improvement. '+name+' has never been one to shirk work. I look forward to having such an excellent student in my class for the rest of the year.',
                                           ]))
        if str(word) == "2":
            final += (rand.choice(['Concepts taught in our class seem to come to '+name+' naturally. '+pronouns[2].title()+' intelligence and quick thinking is very appreciated.',
                                    name+' shows innovative thinking, not only retaining knowledge from previous units but applying that old knowledge skillfully in new situations. This sort of quick thinking serves '+pronouns[1]+' well in the class.',
                                    name+' is a quick and very intuitive problem solver. Answers come easily to '+pronouns[1]+', who displays a great talent for finding the quickest and most efficient path through any given question.',
                                          ]))
        if str(word) == "3":
            final += (rand.choice(['Whenever we have a project that involves teamwork and collaboration, '+name+' rises to the challenge and shows '+pronouns[2]+' unique brand of leadership. When leading by example, others look up to '+pronouns[1]+' and are inspired to do better.',
                                    'No matter who is in the group, '+name+' seems to get along with teammates. Working with others comes naturally to '+pronouns[1]+'. Keep up the good work, '+name+'!',
                                    'Leading seems to come naturally to '+name+'. Throughout the semester, others have observed how assertive and committed '+pronouns[0]+' can be. Whether it is organizing others, keeping teammates on-task, or encouraging people, '+name+' has really stepped up in group work.',
                                          ]))
        if str(word) == "4":
            final += (rand.choice(['While many emphasize test literacy and intelligence as important, we have to remember that the love of learning is also important. '+name+' brings an unrivaled enthusiasm to the room, always curious about concepts and eager to come to class. It is always a pleasure to have '+pronouns[1]+' in class.',
                                    'One aspect often overlooked is the importance of communicating with teachers. When there is a concept '+name+' does not fully understand, there is no hesitation to come to me with questions. The willingness to identify areas of improvement and work on them is commendable.',
                                    'When it comes to learning new concepts, '+name+' does not shy away from them but instead seeks to understand them deeply. '+pronouns[2].title()+' efforts go above and beyond basic comprehension, often even doing projects that add a little extra outside of the curriculum.',
                                          ]))
    return(final)


with open('comments.txt','w') as comments:
    for row in data:
        comments.write(row[0] + '\n')
        comments.write(overall_grade_engagement_collaboration(row) + '\n')
        comments.write(area_to_improve(row) + '\n')
        comments.write(character_traits(row) + '\n')
        comments.write('\n')

f.close()
